# %%
import numpy as np
import pandas as pd

# %%
file=r"C:\Users\G P DOMBALE\Desktop\Python\Datasets\Consumer_train.csv"

# %%
ld=pd.read_csv(file)

# %%
ld
# Out:
#        Date received                  Product                  Sub-product  \
# 0         15-05-2014              Credit card                          NaN
# 1         18-09-2014  Bank account or service  (CD) Certificate of deposit
# 2         13-03-2014         Credit reporting                          NaN
# 3         17-07-2015              Credit card                          NaN
# 4         20-11-2014              Credit card                          NaN
# ...              ...                      ...                          ...
# 478416    30-06-2015  Bank account or service             Checking account
# 478417    20-06-2013              Credit card                          NaN
# 478418    09-09-2014         Credit reporting                          NaN
# 478419    21-09-2012                 Mortgage  Conventional fixed mortgage
# 478420    30-10-2014            Consumer Loan                Vehicle lease
#
# ...

# %%
ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478421 entries, 0 to 478420
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 478421 non-null  object
#  1   Product                       478421 non-null  object
#  2   Sub-product                   339948 non-null  object
#  3   Issue                         478421 non-null  object
#  4   Sub-issue                     185796 non-null  object
#  5   Consumer complaint narrative  75094 non-null   object
#  6   Company public response       90392 non-null   object
#  7   Company                       478421 non-null  object
#  8   State                         474582 non-null  object
#  9   ZIP code                      474573 non-null  object
#  10  Tags                          67206 non-null   object
#  11  Consumer consent provided?    135487 non-null  object
# ...

# %%
ld['Product'].value_counts()
# Out:
# Mortgage                   156175
# Debt collection             86544
# Credit reporting            81115
# Credit card                 57358
# Bank account or service     54403
# Consumer Loan               18599
# Student loan                14918
# Money transfers              3349
# Payday loan                  3219
# Prepaid card                 2226
# Other financial service       507
# Virtual currency                8
# Name: Product, dtype: int64

# %%
k=ld['State'].value_counts()

# %%
ld['State'].value_counts()
# Out:
# CA    70001
# FL    46089
# TX    35895
# NY    32750
# GA    21258
#       ...
# MH       25
# MP       15
# AS       14
# PW        9
# AA        8
# Name: State, Length: 62, dtype: int64

# %%
k.index[k>400]
# Out:
# Index(['CA', 'FL', 'TX', 'NY', 'GA', 'NJ', 'PA', 'IL', 'VA', 'MD', 'OH', 'NC',
#        'MI', 'AZ', 'WA', 'MA', 'CO', 'TN', 'MO', 'SC', 'NV', 'OR', 'MN', 'CT',
#        'IN', 'WI', 'AL', 'LA', 'KY', 'OK', 'DC', 'UT', 'DE', 'NH', 'NM', 'KS',
#        'MS', 'AR', 'IA', 'ID', 'ME', 'HI', 'RI', 'NE', 'WV', 'PR', 'VT', 'MT',
#        'SD', 'AK', 'WY', 'ND'],
#       dtype='object')

# %%
(k>400).sum()
# Out:
# 52

# %%
c=ld['Company'].value_counts()

# %%
ld['Company'].value_counts()
# Out:
# Bank of America                         46336
# Wells Fargo & Company                   35453
# JPMorgan Chase & Co.                    28852
# Equifax                                 28832
# Experian                                26794
#                                         ...
# Sunlan Corporation                          1
# Century Financial Group                     1
# Platinum Finance Company, LLC               1
# Law Office of Cynthia Hitt Kent, LLC        1
# Advance Title & Abstract, Inc.              1
# Name: Company, Length: 3276, dtype: int64

# %%
(c>1).sum()
# Out:
# 2484

# %%
ld['Company response to consumer'].value_counts()
# Out:
# Closed with explanation            354310
# Closed with non-monetary relief     61491
# Closed with monetary relief         32925
# Closed without relief               14145
# Closed                              11365
# Closed with relief                   4184
# Untimely response                       1
# Name: Company response to consumer, dtype: int64

# %%
ld['Submitted via'].value_counts()
# Out:
# Web            313916
# Referral        91352
# Phone           34417
# Postal mail     31448
# Fax              7032
# Email             256
# Name: Submitted via, dtype: int64

# %%
ld.fillna('missing')
# Out:
#        Date received                  Product                  Sub-product  \
# 0         15-05-2014              Credit card                      missing
# 1         18-09-2014  Bank account or service  (CD) Certificate of deposit
# 2         13-03-2014         Credit reporting                      missing
# 3         17-07-2015              Credit card                      missing
# 4         20-11-2014              Credit card                      missing
# ...              ...                      ...                          ...
# 478416    30-06-2015  Bank account or service             Checking account
# 478417    20-06-2013              Credit card                      missing
# 478418    09-09-2014         Credit reporting                      missing
# 478419    21-09-2012                 Mortgage  Conventional fixed mortgage
# 478420    30-10-2014            Consumer Loan                Vehicle lease
#
# ...

# %%
ld['Sub-issue'].value_counts()
# Out:
# Account status                              22891
# Debt is not mine                            22333
# Information is not mine                     17625
# Not given enough info to verify debt        11124
# Debt was paid                                9885
#                                             ...
# Contacted me instead of my attorney           144
# Received marketing offer after opted out      117
# Report shared with employer w/o consent       107
# Qualify for a better loan than offered         97
# Insurance terms                                 4
# Name: Sub-issue, Length: 68, dtype: int64

# %%
ld['Consumer complaint narrative'].value_counts()
# Out:
# This company continues to report on my credit report after I sent them a letter telling them that this account was not mine and I have no idea what it is or who it belongs to! \n\nI asked for proof of a signed contract, I asked for a license to collect in my state, I asked for copies of all information referenced for this debt and still to date, I have not received anything but harassment from this company! \n\nTHIS IS NOT MY DEBT! \n\nI WANT THIS ACCOUNT REMOVED FROM MY CREDIT REPORT AND THIS COMPANY TO STOP CONTACTING ME IMMEDIATELY! \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
# ...

# %%
ld['Consumer disputed?'].value_counts()
# Out:
# No     376990
# Yes    101431
# Name: Consumer disputed?, dtype: int64
