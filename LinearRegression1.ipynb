# %%
import numpy as np
import pandas as pd

# %%
train_file=r"C:\Users\G P DOMBALE\Desktop\Python\Datasets\loan_data_train.csv"
test_file=r"C:\Users\G P DOMBALE\Desktop\Python\Datasets\loan_data_test.csv"

# %%
ld_train=pd.read_csv(train_file)
ld_test=pd.read_csv(test_file)

# %%
ld_test.head()
# Out:
#       ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0  20093              5000                       5000   60 months
# 1  62445             18000                      18000   60 months
# 2  65248              7200                       7200   60 months
# 3  81822              7200                       7200   36 months
# 4  57923             22000                      22000   60 months
#
#          Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0              moving               12.59%    NY           RENT
# 1  debt_consolidation                4.93%    CA           RENT
# 2  debt_consolidation               25.16%    LA       MORTGAGE
# 3  debt_consolidation               17.27%    NY       MORTGAGE
# 4  debt_consolidation               18.28%    MI       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0         4416.67    690-694                13                      7686
# ...

# %%
ld_train.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  79542.0            25000                      25000        18.49%
# 1  75473.0            19750                      19750        17.27%
# 2  67265.0             2100                       2100        14.33%
# 3  80167.0            28000                      28000        16.29%
# 4  17240.0            24250                   17431.82        12.23%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   60 months  debt_consolidation               27.56%    VA       MORTGAGE
# 1   60 months  debt_consolidation               13.39%    NY       MORTGAGE
# 2   36 months      major_purchase                3.50%    LA            OWN
# 3   36 months         credit_card               19.62%    NV       MORTGAGE
# 4   60 months         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
#combine datas
ld_test['Interest.Rate']=np.nan

# %%
ld_test
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0    20093              5000                       5000   60 months
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# ..     ...               ...                        ...         ...
# 295  24675             12000                      11975   60 months
# 296  69456              5000                       5000   36 months
# 297  97954              4375                       4375   36 months
# 298  36931             13600                      13600   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0                moving               12.59%    NY           RENT
# ...

# %%
#will arrange columns as in train
ld_test=ld_test[ld_train.columns]

# %%
ld_test
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors  Interest.Rate  \
# 0    20093              5000                       5000            NaN
# 1    62445             18000                      18000            NaN
# 2    65248              7200                       7200            NaN
# 3    81822              7200                       7200            NaN
# 4    57923             22000                      22000            NaN
# ..     ...               ...                        ...            ...
# 295  24675             12000                      11975            NaN
# 296  69456              5000                       5000            NaN
# 297  97954              4375                       4375            NaN
# 298  36931             13600                      13600            NaN
# 299  34744              6000                       6000            NaN
#
#     Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# ...

# %%
ld_test['data']='test'
# Out:
# C:\Users\G P DOMBALE\AppData\Local\Temp\ipykernel_19800\4001779435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ld_test['data']='test'

# %%
ld_test
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors  Interest.Rate  \
# 0    20093              5000                       5000            NaN
# 1    62445             18000                      18000            NaN
# 2    65248              7200                       7200            NaN
# 3    81822              7200                       7200            NaN
# 4    57923             22000                      22000            NaN
# ..     ...               ...                        ...            ...
# 295  24675             12000                      11975            NaN
# 296  69456              5000                       5000            NaN
# 297  97954              4375                       4375            NaN
# 298  36931             13600                      13600            NaN
# 299  34744              6000                       6000            NaN
#
#     Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# ...

# %%
ld_train['data']='train'

# %%
ld_train
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
ld_all=pd.concat([ld_train,ld_test],axis=0)

# %%
ld_all.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  79542.0            25000                      25000        18.49%
# 1  75473.0            19750                      19750        17.27%
# 2  67265.0             2100                       2100        14.33%
# 3  80167.0            28000                      28000        16.29%
# 4  17240.0            24250                   17431.82        12.23%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   60 months  debt_consolidation               27.56%    VA       MORTGAGE
# 1   60 months  debt_consolidation               13.39%    NY       MORTGAGE
# 2   36 months      major_purchase                3.50%    LA            OWN
# 3   36 months         credit_card               19.62%    NV       MORTGAGE
# 4   60 months         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
k=ld_all['FICO.Range']

# %%
k
# Out:
# 0      720-724
# 1      710-714
# 2      690-694
# 3      710-714
# 4      730-734
#         ...
# 295    705-709
# 296    705-709
# 297    670-674
# 298    675-679
# 299    675-679
# Name: FICO.Range, Length: 2500, dtype: object

# %%
w = (k.str.split('-',expand=True)).astype(float)
#k.str.split('-',expand=True).astype=True

# %%
w
# Out:
#          0      1
# 0    720.0  724.0
# 1    710.0  714.0
# 2    690.0  694.0
# 3    710.0  714.0
# 4    730.0  734.0
# ..     ...    ...
# 295  705.0  709.0
# 296  705.0  709.0
# 297  670.0  674.0
# 298  675.0  679.0
# 299  675.0  679.0
#
# [2500 rows x 2 columns]

# %%
fico=0.5*(w[0]+w[1])

# %%
fico
# Out:
# 0      722.0
# 1      712.0
# 2      692.0
# 3      712.0
# 4      732.0
#        ...
# 295    707.0
# 296    707.0
# 297    672.0
# 298    677.0
# 299    677.0
# Length: 2500, dtype: float64

# %%
ld_all['Fico']=fico

# %%
del ld_all['FICO.Range']

# %%
l=ld_all['Employment.Length']

# %%
e=l.str.split(' years', expand= True)

# %%
f=e[0].str.split(' year', expand= True)

# %%
g=f[0].str.split('+', expand=True)

# %%
Employee_Len=g[0]

# %%
ld_all.drop(['ID'],axis=1,inplace=True)

# %%
ld_all['Employee_Len'] = Employee_Len
del ld_all['Employment.Length']

# %%
j=ld_all['Debt.To.Income.Ratio']

# %%
r=j.str.split('%', expand=True)

# %%
p=pd.to_numeric(r[0])

# %%
ld_all['Debt.To.Income.Ratio']=p

# %%
del ld_all['Amount.Funded.By.Investors']

# %%
ld_all
# Out:
#     Amount.Requested Interest.Rate Loan.Length        Loan.Purpose  \
# 0              25000        18.49%   60 months  debt_consolidation
# 1              19750        17.27%   60 months  debt_consolidation
# 2               2100        14.33%   36 months      major_purchase
# 3              28000        16.29%   36 months         credit_card
# 4              24250        12.23%   60 months         credit_card
# ..               ...           ...         ...                 ...
# 295            12000           NaN   60 months    home_improvement
# 296             5000           NaN   36 months  debt_consolidation
# 297             4375           NaN   36 months         credit_card
# 298            13600           NaN   60 months         credit_card
# 299             6000           NaN   36 months  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# 0                   27.56    VA       MORTGAGE         8606.56
# ...

# %%
ld_all['Interest.Rate']=ld_all['Interest.Rate'].str.replace('%','')

# %%
ld_all
# Out:
#     Amount.Requested Interest.Rate Loan.Length        Loan.Purpose  \
# 0              25000         18.49   60 months  debt_consolidation
# 1              19750         17.27   60 months  debt_consolidation
# 2               2100         14.33   36 months      major_purchase
# 3              28000         16.29   36 months         credit_card
# 4              24250         12.23   60 months         credit_card
# ..               ...           ...         ...                 ...
# 295            12000           NaN   60 months    home_improvement
# 296             5000           NaN   36 months  debt_consolidation
# 297             4375           NaN   36 months         credit_card
# 298            13600           NaN   60 months         credit_card
# 299             6000           NaN   36 months  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# 0                   27.56    VA       MORTGAGE         8606.56
# ...

# %%
ld_all.dtypes
# Out:
# Amount.Requested                   object
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio              float64
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance           object
# Inquiries.in.the.Last.6.Months    float64
# data                               object
# Fico                              float64
# Employee_Len                       object
# dtype: object

# %%
for col in ['Amount.Requested', 'Interest.Rate', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance']:
    ld_all[col]=pd.to_numeric(ld_all[col], errors='coerce')

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49   60 months  debt_consolidation
# 1             19750.0          17.27   60 months  debt_consolidation
# 2              2100.0          14.33   36 months      major_purchase
# 3             28000.0          16.29   36 months         credit_card
# 4             24250.0          12.23   60 months         credit_card
# ..                ...            ...         ...                 ...
# 295           12000.0            NaN   60 months    home_improvement
# 296            5000.0            NaN   36 months  debt_consolidation
# 297            4375.0            NaN   36 months         credit_card
# 298           13600.0            NaN   60 months         credit_card
# 299            6000.0            NaN   36 months  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# 0                   27.56    VA       MORTGAGE         8606.56
# ...

# %%
ld_all['Employee_Len']=ld_all['Employee_Len'].str.replace('<','')

# %%
ld_all['Employee_Len']=pd.to_numeric(ld_all['Employee_Len'],errors='coerce')

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49   60 months  debt_consolidation
# 1             19750.0          17.27   60 months  debt_consolidation
# 2              2100.0          14.33   36 months      major_purchase
# 3             28000.0          16.29   36 months         credit_card
# 4             24250.0          12.23   60 months         credit_card
# ..                ...            ...         ...                 ...
# 295           12000.0            NaN   60 months    home_improvement
# 296            5000.0            NaN   36 months  debt_consolidation
# 297            4375.0            NaN   36 months         credit_card
# 298           13600.0            NaN   60 months         credit_card
# 299            6000.0            NaN   36 months  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# 0                   27.56    VA       MORTGAGE         8606.56
# ...

# %%
cat_cols=ld_all.select_dtypes(['object']).columns
cat_cols
# Out:
# Index(['Loan.Length', 'Loan.Purpose', 'State', 'Home.Ownership', 'data'], dtype='object')

# %%
cat_cols=cat_cols[:-1]
cat_cols
# Out:
# Index(['Loan.Length', 'Loan.Purpose', 'State', 'Home.Ownership'], dtype='object')

# %%
freqs=ld_all['Loan.Length'].value_counts()
freqs
# Out:
# 36 months    1950
# 60 months     548
# .               1
# Name: Loan.Length, dtype: int64

# %%
k=freqs.index[freqs>20][:-1]
k
# Out:
# Index(['36 months'], dtype='object')

# %%
ld_all['Loan.Length 36 months']=(ld_all['Loan.Length']=='36 months').astype(int)

# %%
ld_all['Loan.Length']=ld_all['Loan.Length 36 months']

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate  Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49            0  debt_consolidation
# 1             19750.0          17.27            0  debt_consolidation
# 2              2100.0          14.33            1      major_purchase
# 3             28000.0          16.29            1         credit_card
# 4             24250.0          12.23            0         credit_card
# ..                ...            ...          ...                 ...
# 295           12000.0            NaN            0    home_improvement
# 296            5000.0            NaN            1  debt_consolidation
# 297            4375.0            NaN            1         credit_card
# 298           13600.0            NaN            0         credit_card
# 299            6000.0            NaN            1  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# ...

# %%
freqs=ld_all['Loan.Purpose'].value_counts()
freqs
# Out:
# debt_consolidation    1307
# credit_card            444
# other                  200
# home_improvement       152
# major_purchase         101
# small_business          87
# car                     50
# wedding                 39
# medical                 30
# moving                  29
# vacation                21
# house                   20
# educational             15
# renewable_energy         4
# Name: Loan.Purpose, dtype: int64

# %%
k=freqs.index[freqs>20][:-1]
k
# Out:
# Index(['debt_consolidation', 'credit_card', 'other', 'home_improvement',
#        'major_purchase', 'small_business', 'car', 'wedding', 'medical',
#        'moving'],
#       dtype='object')

# %%
ld_all['Loan.Purpose']=='debt_consolidation'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296     True
# 297    False
# 298    False
# 299     True
# Name: Loan.Purpose, Length: 2500, dtype: bool

# %%
ld_all['Loan.Purpose debt_consolidation']=(ld_all['Loan.Purpose']=='debt_consolidation').astype(int)
ld_all['Loan.Purpose debt_consolidation']
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 295    0
# 296    1
# 297    0
# 298    0
# 299    1
# Name: Loan.Purpose debt_consolidation, Length: 2500, dtype: int32

# %%
ld_all['Loan.Purpose credit_card']=(ld_all['Loan.Purpose']=='credit_card').astype(int)

# %%
ld_all['Loan.Purpose credit_card']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 295    0
# 296    0
# 297    1
# 298    1
# 299    0
# Name: Loan.Purpose credit_card, Length: 2500, dtype: int32

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate  Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49            0  debt_consolidation
# 1             19750.0          17.27            0  debt_consolidation
# 2              2100.0          14.33            1      major_purchase
# 3             28000.0          16.29            1         credit_card
# 4             24250.0          12.23            0         credit_card
# ..                ...            ...          ...                 ...
# 295           12000.0            NaN            0    home_improvement
# 296            5000.0            NaN            1  debt_consolidation
# 297            4375.0            NaN            1         credit_card
# 298           13600.0            NaN            0         credit_card
# 299            6000.0            NaN            1  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# ...

# %%
ld_all['Loan.Purpose home_improvement']=(ld_all['Loan.Purpose']=='home_improvement').astype(int)

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate  Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49            0  debt_consolidation
# 1             19750.0          17.27            0  debt_consolidation
# 2              2100.0          14.33            1      major_purchase
# 3             28000.0          16.29            1         credit_card
# 4             24250.0          12.23            0         credit_card
# ..                ...            ...          ...                 ...
# 295           12000.0            NaN            0    home_improvement
# 296            5000.0            NaN            1  debt_consolidation
# 297            4375.0            NaN            1         credit_card
# 298           13600.0            NaN            0         credit_card
# 299            6000.0            NaN            1  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# ...

# %%
ld_all['Loan.Purpose major_purchase']=(ld_all['Loan.Purpose']=='major_purchase').astype(int)

# %%
ld_all['Loan.Purpose home_improvement']=(ld_all['Loan.Purpose']=='home_improvement').astype(int)

# %%
ld_all
# Out:
#      Amount.Requested  Interest.Rate  Loan.Length        Loan.Purpose  \
# 0             25000.0          18.49            0  debt_consolidation
# 1             19750.0          17.27            0  debt_consolidation
# 2              2100.0          14.33            1      major_purchase
# 3             28000.0          16.29            1         credit_card
# 4             24250.0          12.23            0         credit_card
# ..                ...            ...          ...                 ...
# 295           12000.0            NaN            0    home_improvement
# 296            5000.0            NaN            1  debt_consolidation
# 297            4375.0            NaN            1         credit_card
# 298           13600.0            NaN            0         credit_card
# 299            6000.0            NaN            1  debt_consolidation
#
#      Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# ...
